# %%
# import os
# os.environ['EPICS_CA_ADDR_LIST'] += ' 10.30.18.202'
# os.environ['EPICS_CA_ADDR_LIST']

# %%
from siriuspy.devices.beamline import Slit, Mirror, DVF
import matplotlib.pyplot as plt

# %%
mirror = Mirror(devname=Mirror.DEVICES.MIRROR1)

slit1 = Slit(devname=Slit.DEVICES.SLIT1)
slit2 = Slit(devname=Slit.DEVICES.SLIT2)

dvf1 = DVF(DVF.DEVICES.CAX_DVF1)
dvf2 = DVF(DVF.DEVICES.CAX_DVF2)

# %%
mirror.temperature_2
# Out:
# 23.38897705078125

# %%
dvf1.PROPERTIES_DEFAULT
# Out:
# ('cam1:MaxSizeX_RBV',
#  'cam1:MaxSizeY_RBV',
#  'cam1:SizeX',
#  'cam1:SizeX_RBV',
#  'cam1:SizeY',
#  'cam1:SizeY_RBV',
#  'cam1:MinX',
#  'cam1:MinX_RBV',
#  'cam1:MinY',
#  'cam1:MinY_RBV',
#  'cam1:PortName_RBV',
#  'cam1:ArrayCallbacks',
#  'cam1:ArrayCallbacks_RBV',
#  'cam1:AcquireTime',
#  'cam1:AcquireTime_RBV',
#  'cam1:AcquirePeriod',
#  'cam1:AcquirePeriod_RBV',
#  'cam1:Acquire',
#  'cam1:Acquire_RBV',
#  'cam1:ImageMode',
#  'cam1:ImageMode_RBV',
#  'cam1:Gain',
#  'cam1:Gain_RBV',
#  'cam1:GainAuto',
#  'cam1:GainAuto_RBV',
#  'cam1:PixelFormat',
#  'cam1:PixelFormat_RBV',
#  'cam1:GC_TemperatureAbs_RBV',
#  'cam1:ARFrameFailures',
#  'cam1:ARFramesCompleted',
#  'image1:NDArrayPort',
#  'image1:NDArrayPort_RBV',
#  'image1:EnableCallbacks',
#  'image1:EnableCallbacks_RBV',
#  'image1:ArraySize0_RBV',
#  'image1:ArraySize1_RBV',
#  'image1:DataType_RBV',
#  'image1:ArrayData',
#  'ROI1:PortName_RBV',
#  'ROI1:NDArrayPort',
#  'ROI1:NDArrayPort_RBV',
# ...

# %%
dvf2.PROPERTIES_DEFAULT
# Out:
# ('cam1:MaxSizeX_RBV',
#  'cam1:MaxSizeY_RBV',
#  'cam1:SizeX',
#  'cam1:SizeX_RBV',
#  'cam1:SizeY',
#  'cam1:SizeY_RBV',
#  'cam1:MinX',
#  'cam1:MinX_RBV',
#  'cam1:MinY',
#  'cam1:MinY_RBV',
#  'cam1:PortName_RBV',
#  'cam1:ArrayCallbacks',
#  'cam1:ArrayCallbacks_RBV',
#  'cam1:AcquireTime',
#  'cam1:AcquireTime_RBV',
#  'cam1:AcquirePeriod',
#  'cam1:AcquirePeriod_RBV',
#  'cam1:Acquire',
#  'cam1:Acquire_RBV',
#  'cam1:ImageMode',
#  'cam1:ImageMode_RBV',
#  'cam1:Gain',
#  'cam1:Gain_RBV',
#  'cam1:GainAuto',
#  'cam1:GainAuto_RBV',
#  'cam1:PixelFormat',
#  'cam1:PixelFormat_RBV',
#  'cam1:GC_TemperatureAbs_RBV',
#  'cam1:ARFrameFailures',
#  'cam1:ARFramesCompleted',
#  'image1:NDArrayPort',
#  'image1:NDArrayPort_RBV',
#  'image1:EnableCallbacks',
#  'image1:EnableCallbacks_RBV',
#  'image1:ArraySize0_RBV',
#  'image1:ArraySize1_RBV',
#  'image1:DataType_RBV',
#  'image1:ArrayData',
#  'ROI1:PortName_RBV',
#  'ROI1:NDArrayPort',
#  'ROI1:NDArrayPort_RBV',
# ...

# %%
dvf2.dvf_z_pos

# %%
plt.imshow(dvf1.image)

# %%
mirror._pvs
# Out:
# {RIO01:9226B:temp4: <PV 'CAX:A:RIO01:9226B:temp4', count=1, type=time_double, access=read/write>,
#  'PP01:E.VAL': <PV 'CAX:A:PP01:PP01:E.VAL': not connected>,
#  'PP01:A.STOP': <PV 'CAX:A:PP01:PP01:A.STOP': not connected>,
#  'PP01:D.STOP': <PV 'CAX:A:PP01:PP01:D.STOP': not connected>,
#  RIO01:M1_CtrltempSp: <PV 'CAX:A:RIO01:M1_CtrltempSp', count=1, type=time_double, access=read/write>,
#  RIO01:M1_CtrltempSp: <PV 'CAX:A:RIO01:M1_CtrltempSp', count=1, type=time_double, access=read/write>,
#  'PP01:C.STOP': <PV 'CAX:A:PP01:PP01:C.STOP': not connected>,
#  'PP01:A.VAL': <PV 'CAX:A:PP01:PP01:A.VAL': not connected>,
#  'PP01:C.VAL': <PV 'CAX:A:PP01:PP01:C.VAL': not connected>,
#  'PP01:A.RBV': <PV 'CAX:A:PP01:PP01:A.RBV': not connected>,
#  'PP01:B.RBV': <PV 'CAX:A:PP01:PP01:B.RBV': not connected>,
#  'PP01:B.STOP': <PV 'CAX:A:PP01:PP01:B.STOP': not connected>,
#  'PP01:C.RBV': <PV 'CAX:A:PP01:PP01:C.RBV': not connected>,
#  'PP01:E.STOP': <PV 'CAX:A:PP01:PP01:E.STOP': not connected>,
# ...
